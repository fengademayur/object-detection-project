# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !pip install ultralytics

# %%
ROOT_DIR = '/content/drive/MyDrive/Computer_Vision/Projects/data'

# %%
import os
from ultralytics import YOLO

# Load a model
model = YOLO('yolov8n.yaml')

project_path = '/content/drive/MyDrive/Computer_Vision/Projects/runs/detect'

# Use the model
# adam and sgd (mometum = 0.9/0.95)
results = model.train(data=os.path.join(ROOT_DIR, 'data.yaml'), epochs = 100, imgsz=512, batch = 32, lr0 = 0.001, lrf = 0.2, optimizer = 'SGD', momentum =0.95, weight_decay=0.0001, warmup_epochs=3, project=project_path, name='train_output')  # train the model
